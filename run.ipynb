# %%
from genalg.algorithm import GeneticAlgorithm, visualize_solution, visualize_fitness, init_logging
import logging

# %%
init_logging()
try:
    ga = GeneticAlgorithm()
    ga.compute(es_patience=30)
finally:
    logging.shutdown()
# Out:
# 2019-11-03 00:03:22,242 : INFO : Generation 0000. Fitness: 545.0333.
# 2019-11-03 00:03:22,370 : INFO : Generation 0001. Fitness: 499.5942.
# 2019-11-03 00:03:22,492 : INFO : Generation 0002. Fitness: 458.3146.
# 2019-11-03 00:03:22,619 : INFO : Generation 0003. Fitness: 398.1448.
# 2019-11-03 00:03:22,750 : INFO : Generation 0004. Fitness: 398.1448.
# 2019-11-03 00:03:22,882 : INFO : Generation 0005. Fitness: 393.0484.
# 2019-11-03 00:03:23,007 : INFO : Generation 0006. Fitness: 393.0484.
# 2019-11-03 00:03:23,133 : INFO : Generation 0007. Fitness: 387.0771.
# 2019-11-03 00:03:23,257 : INFO : Generation 0008. Fitness: 379.1851.
# 2019-11-03 00:03:23,390 : INFO : Generation 0009. Fitness: 379.1851.
# 2019-11-03 00:03:23,518 : INFO : Generation 0010. Fitness: 379.1851.
# 2019-11-03 00:03:23,649 : INFO : Generation 0011. Fitness: 379.1851.
# 2019-11-03 00:03:23,791 : INFO : Generation 0012. Fitness: 379.1851.
# 2019-11-03 00:03:23,920 : INFO : Generation 0013. Fitness: 379.1851.
# ...

# %%
visualize_solution(ga.evolution)

# %%
visualize_fitness(ga.evolution)
