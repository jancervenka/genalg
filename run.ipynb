# %%
import logging
from genalg.algorithm import (GeneticAlgorithm,
                              visualize_solution,
                              visualize_fitness,
                              init_logging)

# %%
init_logging()
try:
    ga = GeneticAlgorithm(random_state=0)
    ga.compute(es_patience=30)
finally:
    logging.shutdown()
# Out:
# 2020-05-20 17:49:07,678 : INFO : Generation 0000. Fitness: 545.0333.
# 2020-05-20 17:49:07,791 : INFO : Generation 0001. Fitness: 499.5942.
# 2020-05-20 17:49:07,909 : INFO : Generation 0002. Fitness: 458.3146.
# 2020-05-20 17:49:08,031 : INFO : Generation 0003. Fitness: 398.1448.
# 2020-05-20 17:49:08,153 : INFO : Generation 0004. Fitness: 398.1448.
# 2020-05-20 17:49:08,263 : INFO : Generation 0005. Fitness: 393.0484.
# 2020-05-20 17:49:08,376 : INFO : Generation 0006. Fitness: 393.0484.
# 2020-05-20 17:49:08,492 : INFO : Generation 0007. Fitness: 387.0771.
# 2020-05-20 17:49:08,633 : INFO : Generation 0008. Fitness: 379.1851.
# 2020-05-20 17:49:08,743 : INFO : Generation 0009. Fitness: 379.1851.
# 2020-05-20 17:49:08,862 : INFO : Generation 0010. Fitness: 379.1851.
# 2020-05-20 17:49:08,985 : INFO : Generation 0011. Fitness: 379.1851.
# 2020-05-20 17:49:09,108 : INFO : Generation 0012. Fitness: 379.1851.
# 2020-05-20 17:49:09,250 : INFO : Generation 0013. Fitness: 379.1851.
# ...

# %%
visualize_solution(ga.evolution)

# %%
visualize_fitness(ga.evolution)
